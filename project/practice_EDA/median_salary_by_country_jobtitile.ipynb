# %%
#import data from the csv file

import pandas as pd
import matplotlib.pyplot as plt

file = "C:\\Users\\aksha\\data_analysis_job_market\\dataset\\data_jobs.csv"
df = pd.read_csv(file)

#1.clean the data by converting the job_posted_date into a datetime object from a string

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_posted_month'] = df.job_posted_date.dt.month

#2.Clean by filling all the job postings with NaN for salary with the median salary on both yearly and hourly salary columns

median_salary_yearly = df['salary_year_avg'].median()
median_salary_hourly = df['salary_hour_avg'].median()

df_filled = df.copy()

df_filled['salary_hour_avg']=df_filled['salary_hour_avg'].fillna(median_salary_hourly)
df_filled['salary_year_avg']=df_filled['salary_year_avg'].fillna(median_salary_yearly)

df_filled.sample(10)
# Out:
#           job_title_short                            job_title  \
# 426922  Software Engineer               Software Test Engineer
# 241804       Data Analyst                   Data & Aai Analyst
# 386633       Data Analyst                         Data Analyst
# 274620       Data Analyst                           Cx Analyst
# 585715     Data Scientist           Platform & Data Specialist
# 537712      Data Engineer  Google Cloud Platform Data Engineer
# 385744       Data Analyst                         Data Analyst
# 483767   Business Analyst                              Analyst
# 143622   Business Analyst            Business Research Analyst
# 361103      Data Engineer    Data Engineer | Cloud&Engineering
#
#                 job_location                   job_via job_schedule_type  \
# 426922     Bangkok, Thailand      via Jobs Trabajo.org         Full-time
# 241804      Lisbon, Portugal  via Empregos Trabajo.org         Full-time
# ...

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 718458             Data Scientist
# 677197          Software Engineer
# 318904             Data Scientist
# 176227             Data Scientist
# 699693               Data Analyst
# 640373              Data Engineer
# 288378       Senior Data Engineer
# 480388  Machine Learning Engineer
# 580455      Senior Data Scientist
# 26745               Data Engineer
#
#                                                job_title  \
# 718458                      Data Scientist - remote - W2
# 677197                                 Software Engineer
# 318904               People Analytics & Insights Analyst
# 176227                                 Lead Data Science
# 699693               Treasury Reporting and Data Analyst
# 640373                             Data Engineering Lead
# 288378                              Senior Data Engineer
# 480388  Engineering Services Engineer - Machine Learning
# 580455  Senior Lead Data Scientist - Recommender Systems
# ...

# %%
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_filled[ df_filled['salary_year_avg']!=median_salary_yearly].head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %%
df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
# we want plot only for top six countries 

top_countries = df['job_country'].value_counts().head(6).index

df_job_country_salary = df.pivot_table(
                        values = 'salary_year_avg',
                        index = 'job_country',
                        columns = 'job_title_short',
                        aggfunc= 'median'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]

job_titles = ['Data Analyst','Data Engineer','Data Scientist']
df_job_country_salary = df_job_country_salary[job_titles]
df_job_country_salary.plot(kind = 'bar')
plt.ylabel('Median salary ($USD)')
plt.xlabel("")
plt.title('Median salary by country and job titile')
plt.xticks(rotation=45, ha='right')
plt.show()
