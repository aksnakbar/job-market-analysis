# %%
## find the top 5 paying jobs in the US that are remote

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

## read the  date from a csv file into dataframe

file_name = "C:\\Users\\aksha\\data_analysis_job_market\\dataset\\data_jobs.csv"
df = pd.read_csv(file_name)
df.head()

## create another dataframe that only has US jobs

df_US = df[(df['job_country']== 'United States') & (df['job_work_from_home']== True)]
df_US.head()
#df_US_wfh = df_US[df_US['job_work_from_home']== True].copy()
#df_US_wfh.head()
# Out:
#          job_title_short                      job_title job_location           job_via         job_schedule_type  job_work_from_home          search_location      job_posted_date  job_no_degree_mention  job_health_insurance    job_country salary_rate  salary_year_avg  salary_hour_avg                company_name                                         job_skills                                    job_type_skills
# 5          Data Engineer              GCP Data Engineer     Anywhere  via ZipRecruiter  Contractor and Temp work                True                  Georgia  2023-11-07 14:01:59                  False                 False  United States         NaN              NaN              NaN             smart folks inc                           ['python', 'sql', 'gcp']  {'cloud': ['gcp'], 'programming': ['python', '...
# ...
